# %% [markdown]
# # Transfer Learning Tutorial

# %%
# data가 많이 없을 때 다른 데이터로 훈련시키고 튜닝하여 훈련
# 데이터 부족할때 훈련시켜보기 vs 다른데이터로 훈련시키고 다시 훈련시켜보기
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms

# This mounts your google drive storage to this code
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")

root = '/content/gdrive/My Drive/Test/'
# Out:
# Using cuda device

# %% [markdown]
# First, Let's classify "STL10" dataset **without** transfer learning

# %%
# DATA LOAD (STL10 Dataset) 96X96X3 클래스10개 클래스당 500개 => 총5000개 데이터 => 충분히 훈련안됨 test데이터는 8000개

# settings for data normalization
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)), #(x-m/시그마) 각각 RGB에 넣어주기)
    # transforms.Resize((96,96))
])


train_data = datasets.STL10(
    root=root, 
    split='train',
    download=True, 
    transform=transform)

test_data = datasets.STL10(
    root=root,
    split='test',
    download=True, 
    transform=transform)


batch_size = 32
train_loader = torch.utils.data.DataLoader(train_data,batch_size=batch_size,shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data,batch_size=batch_size,shuffle=False)


classes = ('airplane', 'bird', 'car', 'cat',
           'deer', 'dog', 'horse', 'monkey', 'ship', 'truck')


print('Training Data:', len(train_data), 'Test Data', len(test_data))
# Out:
# Downloading http://ai.stanford.edu/~acoates/stl10/stl10_binary.tar.gz to /content/gdrive/My Drive/Test/stl10_binary.tar.gz
# 100%|██████████| 2640397119/2640397119 [02:45<00:00, 15944345.79it/s]
# Extracting /content/gdrive/My Drive/Test/stl10_binary.tar.gz to /content/gdrive/My Drive/Test/
# Files already downloaded and verified
# Training Data: 5000 Test Data 8000

# %%
# visualize some data
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image


images, labels = next(iter(train_loader))   



sample_index = np.random.choice(batch_size, size=12)     # take 12 random sample index
num_samples = sample_index.size

random_samples = images[sample_index].cpu().numpy()

plt.figure(figsize=(12, 12))

# display test samples
for k in range(num_samples):
    plt.subplot(4, 4, k + 1)
    plt.imshow(random_samples[k].reshape(3,96, 96).transpose(1,2,0)/2 + 0.5)
    plt.title("Class: " + str( classes[labels[sample_index[k]].item()])  )
    plt.axis('off')

    
plt.show()

# %%
# define the CNN: 
# two convolution layers followed by two linear layers

class MyConvNet(nn.Module): # LeNet  # nn.Module should be inherited for the neural network configuration so that it can work with backpropagation APIs
    def __init__(self):    # define layers: two conv layers and two linear (fully connected) layers 
        super(MyConvNet, self).__init__()
        self.conv_layers = nn.Sequential(
            nn.Conv2d(3, 32, 5), # 크기 92
            nn.ReLU(),
            nn.MaxPool2d(2,2), # 크기 46
            nn.Conv2d(32, 64, 5), # 크기 42
            nn.ReLU(),
            nn.MaxPool2d(2,2), # 크기 21
            nn.Flatten(),
            nn.Linear(21*21*64, 512),
            nn.Linear(512, 10)
        )

        # weight initialization
        for m in self.modules():
            if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight.data)      # He normalization

    # network connection: two conv layers, each followed by relu and max-pooling with (2x2) kernel, and two linear layer
    def forward(self, x):
        logits = self.conv_layers(x)
        return(logits)


# generate neural net model
model = MyConvNet().to(device)
print(model)
# Out:
# MyConvNet(
#   (conv_layers): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Flatten(start_dim=1, end_dim=-1)
#     (7): Linear(in_features=28224, out_features=512, bias=True)
#     (8): Linear(in_features=512, out_features=10, bias=True)
#   )
# )

# %%
# optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
optimizer = optim.Adam(model.parameters(), lr=1e-3)

criterion = nn.CrossEntropyLoss()

# %%
# training and test

# epoch: 10
# data dimension: batch_size x Channels x Height x Width (NCHW)
for epoch in range(10):
    # training phase
    # model.train()
    current_loss= 0.0
    for batch_num, (x, target) in enumerate(train_loader):
        x, target = x.to(device), target.to(device)   

        out = model(x)                
        loss = criterion(out,target) 

        optimizer.zero_grad()        
        loss.backward()               
        optimizer.step()              
        current_loss += loss          
        
        # display the training loss in every 100 batches
        if (batch_num+1)%100 == 0 or (batch_num+1)%100 == len(train_loader):
            print('epoch: %d, batch_num: %d, current_loss: %.3f' %(epoch, batch_num+1, current_loss/100))
            current_loss = 0.0
    
    
    # test phase
    with torch.no_grad():   
        # model.eval()        
        total_samples = 0.0
        correct_samples = 0.0
        for (x, target) in test_loader:
            x, target = x.to(device), target.to(device)
            out = model(x)              
            pred = torch.argmax(out,1)  
            correct_samples += (pred == target).sum() 
        print('Accuracy: %.3f' %(100*float(correct_samples) / float(len(test_data))))
# Out:
# epoch: 0, batch_num: 100, current_loss: 5.511
# Accuracy: 10.000
# epoch: 1, batch_num: 100, current_loss: 2.304
# Accuracy: 10.000
# epoch: 2, batch_num: 100, current_loss: 2.305
# Accuracy: 10.025
# epoch: 3, batch_num: 100, current_loss: 2.304
# Accuracy: 12.300
# epoch: 4, batch_num: 100, current_loss: 2.198
# Accuracy: 24.675
# epoch: 5, batch_num: 100, current_loss: 1.994
# Accuracy: 27.350
# epoch: 6, batch_num: 100, current_loss: 1.841
# Accuracy: 27.913
# epoch: 7, batch_num: 100, current_loss: 1.756
# Accuracy: 29.788
# epoch: 8, batch_num: 100, current_loss: 1.616
# Accuracy: 30.275
# epoch: 9, batch_num: 100, current_loss: 1.551
# Accuracy: 31.038

# %%
# Display Some test results 
import numpy as np 
import matplotlib.pyplot as plt


# take one batch of the data
test_data, test_labels = next(iter(test_loader))   

# if cuda_available:
test_data, test_labels = test_data.to(device), test_labels.to(device)
out = model(test_data)              # put the test data to the trained network
pred = torch.argmax(out,1)          # prediction to the highest probability 


sample_index = np.random.choice(batch_size, size=12)     # take 12 random sample index
num_samples = sample_index.size

random_samples = test_data[sample_index].cpu().numpy()

plt.figure(figsize=(12, 12))

# display test samples
for k in range(num_samples):
    plt.subplot(4, 4, k + 1)
    plt.imshow(random_samples[k].reshape(3,96, 96).transpose(1,2,0)/2 + 0.5)
    plt.title("True: " + str( classes[test_labels[sample_index[k]].item()]) + ",\nPred: " + str(classes[pred[sample_index[k]].item()]))
    plt.axis('off')

    
plt.show()

# %% [markdown]
# # Now, Let's try **Transfer Learning**

# %% [markdown]
# 1. Pre-train the network with cifar-10 dataset
# 2. fine-tune with STL10 dataset

# %%
# DATA LOAD (cifar-10 dataset) # 다른 데이터로 pre-training # 사이즈 32X32X3 => 같은 사이즈로 맞춰야됨(96, 96)

# settings for data normalization
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
    transforms.Resize((96,96))
])


train_data = datasets.CIFAR10(
    root=root, 
    train=True,
    download=True, 
    transform=transform)

test_data = datasets.CIFAR10(
    root=root,
    train=False,
    download=True, 
    transform=transform)


batch_size = 32
train_loader = torch.utils.data.DataLoader(train_data,batch_size=batch_size,shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data,batch_size=batch_size,shuffle=False)


classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

print('Training Data:', len(train_data), 'Test Data', len(test_data))
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to /content/gdrive/My Drive/Test/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:12<00:00, 13134311.66it/s]
# Extracting /content/gdrive/My Drive/Test/cifar-10-python.tar.gz to /content/gdrive/My Drive/Test/
# Files already downloaded and verified
# Training Data: 50000 Test Data 10000

# %%
# generate neural net model
model = MyConvNet().to(device) # 여기서 이전 훈련 모델 없어짐
print(model)

# Optimizer
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# Loss Function
criterion = nn.CrossEntropyLoss()
# Out:
# MyConvNet(
#   (conv_layers): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Flatten(start_dim=1, end_dim=-1)
#     (7): Linear(in_features=28224, out_features=512, bias=True)
#     (8): Linear(in_features=512, out_features=10, bias=True)
#   )
# )

# %%
# training and test pre-training

# epoch: 5
# data dimension: batch_size x Channels x Height x Width (NCHW)
for epoch in range(5):
    # training phase
    # model.train()
    current_loss= 0.0
    for batch_num, (x, target) in enumerate(train_loader):
        x, target = x.to(device), target.to(device)   

        out = model(x)                
        loss = criterion(out,target) 

        optimizer.zero_grad()        
        loss.backward()               
        optimizer.step()              
        current_loss += loss          
        
        # display the training loss in every 100 batches
        if (batch_num+1)%100 == 0 or (batch_num+1)%100 == len(train_loader):
            print('epoch: %d, batch_num: %d, current_loss: %.3f' %(epoch, batch_num+1, current_loss/100))
            current_loss = 0.0
    
    
    # test phase
    with torch.no_grad():   
        # model.eval()        
        total_samples = 0.0
        correct_samples = 0.0
        for (x, target) in test_loader:
            x, target = x.to(device), target.to(device)
            out = model(x)              
            pred = torch.argmax(out,1)  
            correct_samples += (pred == target).sum() 
        print('Accuracy: %.3f' %(100*float(correct_samples) / float(len(test_data))))
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# epoch: 0, batch_num: 100, current_loss: 3.861
# epoch: 0, batch_num: 200, current_loss: 2.060
# epoch: 0, batch_num: 300, current_loss: 1.990
# epoch: 0, batch_num: 400, current_loss: 1.985
# epoch: 0, batch_num: 500, current_loss: 1.882
# epoch: 0, batch_num: 600, current_loss: 1.834
# epoch: 0, batch_num: 700, current_loss: 1.798
# epoch: 0, batch_num: 800, current_loss: 1.792
# epoch: 0, batch_num: 900, current_loss: 1.722
# epoch: 0, batch_num: 1000, current_loss: 1.695
# epoch: 0, batch_num: 1100, current_loss: 1.682
# epoch: 0, batch_num: 1200, current_loss: 1.634
# epoch: 0, batch_num: 1300, current_loss: 1.553
# epoch: 0, batch_num: 1400, current_loss: 1.520
# epoch: 0, batch_num: 1500, current_loss: 1.506
# Accuracy: 49.800
# epoch: 1, batch_num: 100, current_loss: 1.396
# epoch: 1, batch_num: 200, current_loss: 1.327
# epoch: 1, batch_num: 300, current_loss: 1.348
# epoch: 1, batch_num: 400, current_loss: 1.328
# epoch: 1, batch_num: 500, current_loss: 1.313
# epoch: 1, batch_num: 600, current_loss: 1.331
# epoch: 1, batch_num: 700, current_loss: 1.288
# epoch: 1, batch_num: 800, current_loss: 1.281
# epoch: 1, batch_num: 900, current_loss: 1.267
# epoch: 1, batch_num: 1000, current_loss: 1.203
# epoch: 1, batch_num: 1100, current_loss: 1.223
# epoch: 1, batch_num: 1200, current_loss: 1.194
# epoch: 1, batch_num: 1300, current_loss: 1.245
# epoch: 1, batch_num: 1400, current_loss: 1.187
# epoch: 1, batch_num: 1500, current_loss: 1.168
# Accuracy: 58.730
# epoch: 2, batch_num: 100, current_loss: 0.978
# epoch: 2, batch_num: 200, current_loss: 1.022
# epoch: 2, batch_num: 300, current_loss: 0.991
# epoch: 2, batch_num: 400, current_loss: 1.004
# epoch: 2, batch_num: 500, current_loss: 1.037
# epoch: 2, batch_num: 600, current_loss: 1.032
# epoch: 2, batch_num: 700, current_loss: 1.084
# epoch: 2, batch_num: 800, current_loss: 1.023
# epoch: 2, batch_num: 900, current_loss: 1.038
# epoch: 2, batch_num: 1000, current_loss: 1.026
# epoch: 2, batch_num: 1100, current_loss: 1.013
# epoch: 2, batch_num: 1200, current_loss: 1.072
# epoch: 2, batch_num: 1300, current_loss: 1.028
# epoch: 2, batch_num: 1400, current_loss: 1.048
# epoch: 2, batch_num: 1500, current_loss: 1.062
# Accuracy: 61.480
# epoch: 3, batch_num: 100, current_loss: 0.763
# epoch: 3, batch_num: 200, current_loss: 0.772
# epoch: 3, batch_num: 300, current_loss: 0.814
# epoch: 3, batch_num: 400, current_loss: 0.847
# epoch: 3, batch_num: 500, current_loss: 0.827
# epoch: 3, batch_num: 600, current_loss: 0.839
# epoch: 3, batch_num: 700, current_loss: 0.846
# epoch: 3, batch_num: 800, current_loss: 0.853
# epoch: 3, batch_num: 900, current_loss: 0.860
# epoch: 3, batch_num: 1000, current_loss: 0.838
# epoch: 3, batch_num: 1100, current_loss: 0.900
# epoch: 3, batch_num: 1200, current_loss: 0.893
# epoch: 3, batch_num: 1300, current_loss: 0.920
# epoch: 3, batch_num: 1400, current_loss: 0.847
# epoch: 3, batch_num: 1500, current_loss: 0.916
# Accuracy: 62.440
# epoch: 4, batch_num: 100, current_loss: 0.584
# epoch: 4, batch_num: 200, current_loss: 0.618
# epoch: 4, batch_num: 300, current_loss: 0.630
# epoch: 4, batch_num: 400, current_loss: 0.633
# epoch: 4, batch_num: 500, current_loss: 0.655
# epoch: 4, batch_num: 600, current_loss: 0.692
# epoch: 4, batch_num: 700, current_loss: 0.656
# epoch: 4, batch_num: 800, current_loss: 0.717
# epoch: 4, batch_num: 900, current_loss: 0.704
# epoch: 4, batch_num: 1000, current_loss: 0.725
# epoch: 4, batch_num: 1100, current_loss: 0.737
# epoch: 4, batch_num: 1200, current_loss: 0.694
# epoch: 4, batch_num: 1300, current_loss: 0.734
# epoch: 4, batch_num: 1400, current_loss: 0.753
# epoch: 4, batch_num: 1500, current_loss: 0.733
# Accuracy: 61.700

# %% [markdown]
# Pre-training is done!
#
# Now, Let's fine-tune with STL10 dataset

# %%
print(model)
# Out:
# MyConvNet(
#   (conv_layers): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Flatten(start_dim=1, end_dim=-1)
#     (7): Linear(in_features=28224, out_features=512, bias=True)
#     (8): Linear(in_features=512, out_features=10, bias=True)
#   )
# )

# %%
# Replace the last few layers 분류기가 달라서 이전 마지막 FC출력기만 제거하고 갈아끼웠음


# # model.conv_layers[7] = nn.Linear(21*21*64, 128).to(device)   
model.conv_layers[8] = nn.Linear(512, 10).to(device)       # Replace Last layer

# %%
# Load STL10 data again

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
    # transforms.Resize((96,96))
])

train_data = datasets.STL10(
    root=root, 
    split='train',
    download=True, 
    transform=transform)

test_data = datasets.STL10(
    root=root,
    split='test',
    download=True, 
    transform=transform)


batch_size = 32
train_loader = torch.utils.data.DataLoader(train_data,batch_size=batch_size,shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data,batch_size=batch_size,shuffle=False)


classes = ('airplane', 'bird', 'car', 'cat',
           'deer', 'dog', 'horse', 'monkey', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Optimizer 1e-3 => 1e-4로 작게 변경해야함
optimizer = optim.Adam(model.parameters(), lr=1e-4)

# Loss Function
criterion = nn.CrossEntropyLoss()

# %%
# training and test

# epoch: 5
# data dimension: batch_size x Channels x Height x Width (NCHW)
for epoch in range(5):
    # training phase
    # model.train()
    current_loss= 0.0
    for batch_num, (x, target) in enumerate(train_loader):
        x, target = x.to(device), target.to(device)   

        out = model(x)                
        loss = criterion(out,target) 

        optimizer.zero_grad()        
        loss.backward()               
        optimizer.step()              
        current_loss += loss          
        
        # display the training loss in every 100 batches
        if (batch_num+1)%100 == 0 or (batch_num+1)%100 == len(train_loader):
            print('epoch: %d, batch_num: %d, current_loss: %.3f' %(epoch, batch_num+1, current_loss/100))
            current_loss = 0.0
    
    
    # test phase
    with torch.no_grad():   
        # model.eval()        
        total_samples = 0.0
        correct_samples = 0.0
        for (x, target) in test_loader:
            x, target = x.to(device), target.to(device)
            out = model(x)              
            pred = torch.argmax(out,1)  
            correct_samples += (pred == target).sum() 
        print('Accuracy: %.3f' %(100*float(correct_samples) / float(len(test_data))))
# Out:
# epoch: 0, batch_num: 100, current_loss: 1.946
# Accuracy: 51.837
# epoch: 1, batch_num: 100, current_loss: 1.038
# Accuracy: 57.575
# epoch: 2, batch_num: 100, current_loss: 0.608
# Accuracy: 60.225
# epoch: 3, batch_num: 100, current_loss: 0.320
# Accuracy: 60.237
# epoch: 4, batch_num: 100, current_loss: 0.140
# Accuracy: 60.575
